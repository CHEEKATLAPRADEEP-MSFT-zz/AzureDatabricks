# %%
blob_account_name = "azureopendatastorage"
blob_container_name = "citydatacontainer"
blob_relative_path = "Safety/Release/city=Boston"
blob_sas_token = r"?st=2019-02-26T02%3A34%3A32Z&se=2119-02-27T02%3A34%3A00Z&sp=rl&sv=2018-03-28&sr=c&sig=XlJVWA7fMXCSxCKqJm8psMOh0W4h7cSYO28coRqF2fs%3D"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
wasbs_path = 'wasbs://%s@%s.blob.core.windows.net/%s' % (blob_container_name, blob_account_name, blob_relative_path)
spark.conf.set('fs.azure.sas.%s.%s.blob.core.windows.net' % (blob_container_name, blob_account_name), blob_sas_token)
print('Remote blob path: ' + wasbs_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Remote blob path: wasbs://citydatacontainer@azureopendatastorage.blob.core.windows.net/Safety/Release/city=Boston
# </div>

# %%
df = spark.read.parquet(wasbs_path)
print('Register the DataFrame as a SQL temporary view: source')
df.createOrReplaceTempView('source')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Register the DataFrame as a SQL temporary view: source
# </div>

# %%
print('Displaying top 10 rows: ')
display(spark.sql('SELECT * FROM source LIMIT 10'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dataType</th><th>dataSubtype</th><th>dateTime</th><th>category</th><th>subcategory</th><th>status</th><th>address</th><th>latitude</th><th>longitude</th><th>source</th><th>extendedProperties</th></tr></thead><tbody><tr><td>Safety</td><td>311_All</td><td>2014-11-17T18:31:21.000+0000</td><td>Traffic Management & Engineering</td><td>Requests for Traffic Signal Studies or Reviews</td><td>Closed</td><td>INTERSECTION of Atlantic Ave & Northern Ave  Boston  MA  </td><td>42.3551</td><td>-71.051</td><td>Constituent Call</td><td>null</td></tr><tr><td>Safety</td><td>311_All</td><td>2011-07-08T12:33:43.000+0000</td><td>Highway Maintenance</td><td>Pothole Repair (Internal)</td><td>Closed</td><td>INTERSECTION of Huntington Ave & Massachusetts Ave  Boston  MA  </td><td>42.3427</td><td>-71.0849</td><td>Employee Generated</td><td>null</td></tr><tr><td>Safety</td><td>311_All</td><td>2011-10-11T17:28:51.000+0000</td><td>Street Lights</td><td>Street Light Outages</td><td>Closed</td><td>INTERSECTION of Everton St & Geneva Ave  Dorchester  MA  </td><td>42.304</td><td>-71.0721</td><td>Constituent Call</td><td>null</td></tr><tr><td>Safety</td><td>311_All</td><td>2011-07-02T19:52:31.000+0000</td><td>Sanitation</td><td>Schedule a Bulk Item Pickup</td><td>Closed</td><td>116 Main St  Charlestown  MA  02129</td><td>42.3744</td><td>-71.0638</td><td>Self Service</td><td>null</td></tr><tr><td>Safety</td><td>311_All</td><td>2019-01-24T12:45:21.000+0000</td><td>Sanitation</td><td>Schedule a Bulk Item Pickup SS</td><td>Closed</td><td>9 Helen St  Dorchester  MA  02124</td><td>42.2933</td><td>-71.0805</td><td>Self Service</td><td>null</td></tr><tr><td>Safety</td><td>311_All</td><td>2014-07-24T08:31:42.000+0000</td><td>Recycling</td><td>Request for Recycling Cart</td><td>Closed</td><td>69 Saint James St  Roxbury  MA  02119</td><td>42.3272</td><td>-71.0868</td><td>Constituent Call</td><td>null</td></tr><tr><td>Safety</td><td>311_All</td><td>2011-11-15T08:48:35.000+0000</td><td>Highway Maintenance</td><td>Pothole Repair (Internal)</td><td>Closed</td><td>81 Pleasant Hill Ave  Mattapan  MA  02126</td><td>42.2756</td><td>-71.0723</td><td>Employee Generated</td><td>null</td></tr><tr><td>Safety</td><td>311_All</td><td>2014-07-29T15:23:14.000+0000</td><td>Highway Maintenance</td><td>Empty Litter Basket</td><td>Closed</td><td>INTERSECTION of First Ave & Seventh St  Charlestown  MA  </td><td>42.3753</td><td>-71.0539</td><td>Constituent Call</td><td>null</td></tr><tr><td>Safety</td><td>311_All</td><td>2019-02-14T18:34:46.000+0000</td><td>Code Enforcement</td><td>Improper Storage of Trash (Barrels)</td><td>Closed</td><td>INTERSECTION of Lexington St & Meridian St  East Boston  MA  </td><td>42.3594</td><td>-71.0587</td><td>Citizens Connect App</td><td>null</td></tr><tr><td>Safety</td><td>311_All</td><td>2016-10-17T08:51:46.000+0000</td><td>Sanitation</td><td>Schedule a Bulk Item Pickup SS</td><td>Closed</td><td>11 Park Dr  Boston  MA  02215</td><td>42.3448</td><td>-71.0951</td><td>Self Service</td><td>null</td></tr></tbody></table></div>
